# %%
import pandas as pd

# %%
dfCompliant = pd.read_csv('Data\TotalCompliant.csv', low_memory=False)

# %%
dfCompliant
# Out:
#          1016824  ****DECEASED****  977200009863339  \
# 0        1018079  ****DECEASED****  977200009863339
# 1        1056734  ****DECEASED****  977200009863339
# 2        1057598  ****DECEASED****  977200009863339
# 3        1059579  ****DECEASED****  977200009863339
# 4        1062965  ****DECEASED****  977200009863339
# ...          ...               ...              ...
# 1709501   768201      ZUZUS PETALS  977200009504319
# 1709502   767201      ZUZUS PETALS  977200009504319
# 1709503   772940      ZUZUS PETALS  977200009504319
# 1709504   774226      ZUZUS PETALS  977200009504319
# 1709505   776199      ZUZUS PETALS  977200009504319
#
#                                    Unnamed: 3 Unnamed: 4  B  bk  XKQTL  \
# 0                                         NaN        NaN  B  bk  XKQTL
# 1                                         NaN        NaN  B  bk  XKQTL
# 2                                         NaN        NaN  B  bk  XKQTL
# ...

# %%
dfCompliant.set_axis([['GreyhoundEntry','Name','Microchip','RmsGreyhoundGuid','IccVolumeRegNo','Sex','Colour',
                       'Earmark','OwnrName','OwnrRmsPersonOrgGuid','OwnrIccNumber','Ownr2Name',
                'Ownr2RmsPersonOrgGuid','Ownr2IccNumber','TrainerName','TrainerRmsPersonOrgGuid',
                'TrainerICCNumber','BrdrName','BrdrRmsPersonOrgGuid','BrdrICCNumber','ReminderDate1',
                'ReminderDate2','ReminderDate3','OccuredAt','NoticeSentBy','NoticeSentAt']],
                    axis=1,inplace=True)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_6608\3828405554.py:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   dfCompliant.set_axis([['GreyhoundEntry','Name','Microchip','RmsGreyhoundGuid','IccVolumeRegNo','Sex','Colour',

# %%
#dfCompliant.set_index('Microchip', inplace=True)

# %%
dfCompliant =dfCompliant.drop(['GreyhoundEntry','Name','OwnrName','OwnrRmsPersonOrgGuid','OwnrIccNumber','Ownr2Name',
                'Ownr2RmsPersonOrgGuid','Ownr2IccNumber','TrainerName','TrainerRmsPersonOrgGuid',
                'TrainerICCNumber','BrdrName','BrdrRmsPersonOrgGuid','BrdrICCNumber','ReminderDate1',
                'ReminderDate2','ReminderDate3','NoticeSentBy'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\1521976429.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant =dfCompliant.drop(['GreyhoundEntry','Name','OwnrName','OwnrRmsPersonOrgGuid','OwnrIccNumber','Ownr2Name',

# %%
dfCompliant=dfCompliant.drop(['IccVolumeRegNo'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\4265139843.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant=dfCompliant.drop(['IccVolumeRegNo'],axis=1)

# %%
dfCompliant=dfCompliant.drop(['RmsGreyhoundGuid'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\3385924159.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant=dfCompliant.drop(['RmsGreyhoundGuid'],axis=1)

# %%
dfCompliant=dfCompliant.drop(['Colour'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\2044083636.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant=dfCompliant.drop(['Colour'],axis=1)

# %%
dfCompliant=dfCompliant.drop(['Sex'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\4127348270.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant=dfCompliant.drop(['Sex'],axis=1)

# %%
dfCompliant=dfCompliant.drop(['NoticeSentAt'],axis=1)
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_7352\476008905.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dfCompliant=dfCompliant.drop(['NoticeSentAt'],axis=1)

# %%
dfCompliant
# Out:
#         GreyhoundEntry              Name        Microchip  \
# 0              1018079  ****DECEASED****  977200009863339
# 1              1056734  ****DECEASED****  977200009863339
# 2              1057598  ****DECEASED****  977200009863339
# 3              1059579  ****DECEASED****  977200009863339
# 4              1062965  ****DECEASED****  977200009863339
# ...                ...               ...              ...
# 1709501         768201      ZUZUS PETALS  977200009504319
# 1709502         767201      ZUZUS PETALS  977200009504319
# 1709503         772940      ZUZUS PETALS  977200009504319
# 1709504         774226      ZUZUS PETALS  977200009504319
# 1709505         776199      ZUZUS PETALS  977200009504319
#
#                              RmsGreyhoundGuid IccVolumeRegNo Sex Colour  \
# 0                                         NaN            NaN   B     bk
# 1                                         NaN            NaN   B     bk
# ...

# %%
dfCompliant["OccuredAt"].dtypes
# Out:
# OccuredAt    object
# dtype: object

# %%
dfCompliant["OccuredAt"] = dfCompliant["OccuredAt"].astype(datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dfCompliant["OccuredAt"] = dfCompliant["OccuredAt"].astype(datetime)
#
# NameError: name 'datetime' is not defined

# %%
# Convert 'OccurredAt' column to datetime
dfCompliant["OccuredAt1"] = pd.to_datetime(dfCompliant["OccuredAt"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Convert 'OccurredAt' column to datetime
# ----> 2 dfCompliant["OccuredAt1"] = pd.to_datetime(dfCompliant["OccuredAt"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1071, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1071     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1072 elif isinstance(arg, Index):
#    1073     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1178, in _assemble_from_unit_mappings(arg, errors, tz)
# ...

# %%
dfCompliant.to_csv('Data/Compiant.csv',encoding='utf-8')

# %%
dfTraceability = pd.read_excel('Data\Tracebility.xlsx')

# %%
dfTraceability.to_csv('Data/Traceability.csv',encoding='utf-8')

# %%
dfTraceability = pd.read_csv('Data\Traceability.csv', low_memory=False)

# %%
dfTraceability
# Out:
#        Unnamed: 0    Greyhound Name  ICC VolReg Earmark     Microchip  \
# 0               0      JEWEL MAIDEN   9411917.0   PLPIQ  9.722740e+14
# 1               1       BULLET ENDA    951205.0   QPBVB  9.810981e+14
# 2               2    FLEXIBLE PANGO   9511107.0   QRHSP  9.810981e+14
# 3               3    FLEXIBLE TANGO   9511105.0   QRLED  9.810981e+14
# 4               4       BLACK RIOGA   9512668.0   QPYAK  9.810981e+14
# ...           ...               ...         ...     ...           ...
# 18404       18404               NaN         NaN   YXTMQ  9.772000e+14
# 18405       18405  SPRINGHILL RAPID  10111255.0   YDZAL  9.772000e+14
# 18406       18406               NaN         NaN   YDAHK  9.772000e+14
# 18407       18407               NaN         NaN   YDDJM  9.772000e+14
# 18408       18408               NaN         NaN   YDUZE  9.772000e+14
#
#          Reg Date  Active Colour Sex  Whelp Date Retirement Type  \
# ...

# %%
# Convert 'OccurredAt' column to datetime
dfTraceability["Retirement Created At2"] = pd.to_datetime(dfTraceability["Retirement Created At2"])

# %%
dfCompliant
# Out:
#                Microchip Earmark                OccuredAt
# 0        977200009863339   XKQTL  2022-09-03 06:32:00.000
# 1        977200009863339   XKQTL  2022-09-16 06:32:00.000
# 2        977200009863339   XKQTL  2022-09-16 06:32:00.000
# 3        977200009863339   XKQTL  2022-09-16 06:32:00.000
# 4        977200009863339   XKQTL  2022-09-16 06:32:00.000
# ...                  ...     ...                      ...
# 1709501  977200009504319   VSTTA  2022-05-21 06:32:00.000
# 1709502  977200009504319   VSTTA  2022-05-21 06:32:00.000
# 1709503  977200009504319   VSTTA  2022-05-23 09:33:00.000
# 1709504  977200009504319   VSTTA  2022-05-23 09:33:00.000
# 1709505  977200009504319   VSTTA  2022-05-23 09:33:00.000
#
# [1709506 rows x 3 columns]

# %%
# Convert 'OccurredAt' column to datetime
dfCompliant["OccuredAt"] = pd.to_datetime(dfCompliant["OccuredAt"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Convert 'OccurredAt' column to datetime
# ----> 2 dfCompliant["OccuredAt"] = pd.to_datetime(dfCompliant["OccuredAt"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1071, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1071     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1072 elif isinstance(arg, Index):
#    1073     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1178, in _assemble_from_unit_mappings(arg, errors, tz)
# ...

# %%
df.to_csv('Combined3_DateFrames.csv',encoding='utf-8')

# %%
df=df.drop('Microchip,',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df=df.drop('Microchip,',axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#          Greyhound Name  ICC VolReg Earmark     Microchip   Reg Date  Active  \
# 0          JEWEL MAIDEN   9411917.0   PLPIQ  9.722740e+14 2015-09-29     0.0
# 1           BULLET ENDA    951205.0   QPBVB  9.810981e+14 2016-02-11     0.0
# 2        FLEXIBLE PANGO   9511107.0   QRHSP  9.810981e+14 2016-09-23     0.0
# 3        FLEXIBLE TANGO   9511105.0   QRLED  9.810981e+14 2016-09-23     0.0
# 4           BLACK RIOGA   9512668.0   QPYAK  9.810981e+14 2016-11-02     0.0
# ...                 ...         ...     ...           ...        ...     ...
# 18404               NaN         NaN   YXTMQ  9.772000e+14 2022-07-04     0.0
# 18405  SPRINGHILL RAPID  10111255.0   YDZAL  9.772000e+14 2022-05-29     0.0
# 18406               NaN         NaN   YDAHK  9.772000e+14 2022-07-26     0.0
# 18407               NaN         NaN   YDDJM  9.772000e+14 2022-07-26     0.0
# 18408               NaN         NaN   YDUZE  9.772000e+14 2022-09-02     0.0
#
# ...

# %%
# Convert 'OccurredAt' column to datetime
df["OccurredAt"] = pd.to_datetime(df["OccurredAt"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OccurredAt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = df.sort_values(by=['Microchip','Retirement Created At2'])

# %%
df
# Out:
#                 Greyhound Name  ICC VolReg Earmark_x   Reg Date  Active  \
# Microchip
# 9.410002e+13         LADY NASH         NaN      ZNA4 2021-02-18     0.0
# 9.001330e+14    DASHGROVE LISA         NaN      AJV3 2021-05-25     0.0
# 9.001330e+14       HOUSE ANGEL         NaN      AMR6 2022-02-05     0.0
# 9.002000e+14  FURLOUGH BANDITO         NaN      ZPL2 2021-04-15     0.0
# 9.002000e+14       GRACIE BRAE         NaN      ZPL7 2019-10-10     0.0
# ...                        ...         ...       ...        ...     ...
# NaN                        NaN         NaN       NaN        NaT     NaN
# NaN                        NaN         NaN       NaN        NaT     NaN
# NaN                        NaN         NaN       NaN        NaT     NaN
# NaN                        NaN         NaN       NaN        NaT     NaN
# NaN                        NaN         NaN       NaN        NaT     NaN
#
#              Colour  Sex Whelp Date Retirement Type  Retirement Created At2  \
# Microchip
# ...

# %%
#df
# Out:
#         Earmark                OccuredAt   Greyhound Name  ICC VolReg  \
# 0         XKQTL  2022-09-03 06:32:00.000              NaN         NaN
# 1         XKQTL  2022-09-03 06:32:00.000              NaN         NaN
# 2         XKQTL  2022-09-16 06:32:00.000              NaN         NaN
# 3         XKQTL  2022-09-16 06:32:00.000              NaN         NaN
# 4         XKQTL  2022-09-16 06:32:00.000              NaN         NaN
# ...         ...                      ...              ...         ...
# 1713984   VPISU                      NaN  KNOCKGLASS KING   1002537.0
# 1713985   TDVXR                      NaN     HELLO HOLLIE    996550.0
# 1713986   UYIKE                      NaN      SEOMRA DISC   1002328.0
# 1713987   VVTMH                      NaN     KILWEST NOAH   1001431.0
# 1713988    ZYH2                      NaN      CHEEKY CHAR         NaN
#
#           Reg Date  Active Colour  Sex Whelp Date Retirement Type  \
# ...

# %%
result_df.to_csv('Combined1_DateFrames.csv',encoding='utf-8')

# %%
df1 = pd.read_csv('Combined1_DateFrames.csv')

# %%
df1
# Out:
#        Greyhound Name Earmark     Microchip    Reg Date Sex  Whelp Date  \
# 0        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 1        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 2        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 3        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 4        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# ...               ...     ...           ...         ...  ..         ...
# 234542            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234543            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234544            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234545            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234546            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
#
#        Retirement Type         OccuredAt
# 0                  DIE  21/10/2021 11:11
# ...

# %%
# Group by 'Earmark' and find the first and last dates in each group
grouped = df1.groupby("Earmark")["OccuredAt"].agg(["first", "last"])

# %%
# Initialize a new column 'Status' with 'RAC'
df1["Status"] = "RAC"

# %%
df1
# Out:
#        Greyhound Name Earmark     Microchip    Reg Date Sex  Whelp Date  \
# 0        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 1        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 2        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 3        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 4        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# ...               ...     ...           ...         ...  ..         ...
# 234542            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234543            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234544            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234545            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234546            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
#
#        Retirement Type         OccuredAt Status
# 0                  DIE  21/10/2021 11:11    RAC
# ...

# %%
# Update the 'Status' column for the first and last rows in each group
for index, row in grouped.iterrows():
    #df1.loc[(df1["Earmark"] == index) & (df1["OccuredAt"] == row["first"]), "Status"] = "REG"
    df1.loc[(df1["Earmark"] == index) & (df1["OccuredAt"] == row["last"]), "Status"] = Retirement Type
# Out:
#   Cell In[149], line 4
#     df1.loc[(df1["Earmark"] == index) & (df1["OccuredAt"] == row["last"]), "Status"] = Retirement Type
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
df1
# Out:
#        Greyhound Name Earmark     Microchip    Reg Date Sex  Whelp Date  \
# 0        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 1        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 2        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 3        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 4        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# ...               ...     ...           ...         ...  ..         ...
# 234542            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234543            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234544            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234545            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234546            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
#
#        Retirement Type         OccuredAt Status
# 0                  DIE  21/10/2021 11:11    REG
# ...

# %%
#df1.to_csv('Combined2_DateFrames.csv',encoding='utf-8')
# Convert 'OccurredAt' column to datetime
df["OccuredAt"] = pd.to_datetime(df["OccuredAt"])

# %%
# Group by 'Earmark' and find the last date in each group
grouped1 = df1.groupby("Earmark")["OccuredAt"].agg('last')

# %%
# Update the 'Status' column for the last rows in each group
for index, last_date in grouped1.iteritems():
    last_entry_index = df1[(df1["Earmark"] == index) & (df1["OccuredAt"] == last_date)].index[0]
    retirement_type = df1.at[last_entry_index, "Retirement Type"]
    df1.at[last_entry_index, "Status"] = retirement_type
# Out:
# C:\Users\Daniel Maher\AppData\Local\Temp\ipykernel_11476\4069445755.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, last_date in grouped1.iteritems():
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[158], line 3
#       1 # Update the 'Status' column for the last rows in each group
#       2 for index, last_date in grouped1.iteritems():
# ----> 3     last_entry_index = df1[(df1["Earmark"] == index) & (df1["OccuredAt"] == last_date)].index[0]
#       4     retirement_type = df1.at[last_entry_index, "Retirement Type"]
#       5     df1.at[last_entry_index, "Status"] = retirement_type
#
# File E:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5320, in Index.__getitem__(self, key)
#    5317 if is_integer(key) or is_float(key):
# ...

# %%
# Find the rows where 'OccurredAt' matches the last date in the group
last_date_rows = df1["OccuredAt"] == grouped
# Out:
# C:\Users\Daniel Maher\AppData\Local\Temp\ipykernel_11476\2076184693.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   last_date_rows = df1["OccuredAt"] == grouped
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[163], line 2
#       1 # Find the rows where 'OccurredAt' matches the last date in the group
# ----> 2 last_date_rows = df1["OccuredAt"] == grouped
#
# File E:\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# ...
