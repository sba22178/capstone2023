# %%
import pandas as pd

# %%
#df = pd.read_csv('Data\Combined2_DateFrames.csv', low_memory=False)
df = pd.read_csv('Data\Combined2_DateFrames.csv', low_memory=False)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#        Greyhound Name Earmark     Microchip    Reg Date Sex  Whelp Date  \
# 0        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 1        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 2        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 3        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# 4        JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015   B  22/09/2014
# ...               ...     ...           ...         ...  ..         ...
# 234542            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234543            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234544            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234545            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
# 234546            NaN   YDUZE  9.770000e+14  02/09/2022   D  02/09/2022
#
#        Retirement Type         OccuredAt Status
# 0                  DIE  21/10/2021 11:11    REG
# 1                  DIE  21/10/2021 11:12    RAC
# 2                  DIE  21/10/2021 11:14    RAC
# 3                  DIE  21/10/2021 11:16    RAC
# 4                  DIE  21/10/2021 13:08    RAC
# ...                ...               ...    ...
# 234542             EUT  23/12/2022 06:33    REG
# 234543             EUT  08/01/2023 14:42    RAC
# 234544             EUT  21/02/2023 09:58    RAC
# 234545             EUT  20/05/2023 09:49    RAC
# 234546             EUT  20/05/2023 10:49    RAC
#
# [234547 rows x 9 columns]

# %%
# Convert 'OccurredAt' column to datetime
df["OccuredAt"] = pd.to_datetime(df["OccuredAt"])

# %%
# Sort DataFrame based on 'OccurredAt' in descending order
df = df.sort_values(by="OccuredAt", ascending=False)

# %%
# Find the unique earmarks
unique_earmarks = df["Earmark"].unique()

# %%
# Update 'Status' column for the last entry in each group
for earmark in unique_earmarks:
    last_row_index = df[df["Earmark"] == earmark].index[0]
    df.at[last_row_index, "Status"] = df.at[last_row_index, "Retirement Type"]

# %%
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# %%
df1 = df

# %%
# Write DataFrame to a CSV file with the specified date format
#df.to_csv("output.csv", index=False)

# %%
#df = pd.read_csv('output.csv', low_memory=False)

# %%
import matplotlib.pyplot as plt
# Plot a bar chart to show the distribution of 'Status'
status_counts = df["Status"].value_counts()
status_counts.plot(kind="bar", color="skyblue")
plt.title("Distribution of Status")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# Plot a pie chart to show the proportion of each 'Status'
plt.figure(figsize=(6, 6))
plt.pie(status_counts, labels=status_counts.index, autopct="%1.1f%%", startangle=140, colors=["skyblue", "lightcoral"])
plt.title("Proportion of Status")
plt.show()

# %%
subset = df[['OccuredAt','Status']]

# %%
subset["OccuredAt"] = pd.to_datetime(subset["OccuredAt"]);
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_4612\1398405935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset["OccuredAt"] = pd.to_datetime(subset["OccuredAt"]);

# %%
# Set "OccurredAt" as the index
subset.set_index("OccuredAt", inplace=True)

# %%
# Plot the time series
#plt.figure(figsize=(10, 6))
#plt.plot(subset.index, subset["Status"], marker='o')
#plt.title("Time Series of Status")
#plt.xlabel("Time")
#plt.ylabel("Status")
#plt.grid(True)
#plt.show()

# %%
# Resample the data to a weekly frequency and count the occurrences of each status
#resampled_df = df.resample("W").count()

# %%
df["OccuredAt"] = pd.to_datetime(df["OccuredAt"])

# Set "OccurredAt" as the index
df.set_index("OccuredAt", inplace=True)

# Resample the data to a weekly frequency and count the occurrences of each status
resampled_df = df.resample("W").count()

# %%
resampled_df
# Out:
#             Greyhound Name  Earmark  Microchip  Reg Date  Sex  Whelp Date  \
# OccuredAt
# 2021-01-10              30       30         30        30   30          30
# 2021-01-17              76       76         76        76   76          76
# 2021-01-24               0        0          0         0    0           0
# 2021-01-31               0        0          0         0    0           0
# 2021-02-07               0        0          0         0    0           0
# ...                    ...      ...        ...       ...  ...         ...
# 2023-11-12             238      242        242       238  238         238
# 2023-11-19               0        0          0         0    0           0
# 2023-11-26               0        0          0         0    0           0
# 2023-12-03             605      621        621       618  618         618
# 2023-12-10             588      611        611       605  605         605
#
#             Retirement Type  Status
# OccuredAt
# 2021-01-10               30      30
# 2021-01-17               76      76
# 2021-01-24                0       0
# 2021-01-31                0       0
# 2021-02-07                0       0
# ...                     ...     ...
# 2023-11-12              238     240
# 2023-11-19                0       0
# 2023-11-26                0       0
# 2023-12-03              618     618
# 2023-12-10              603     605
#
# [153 rows x 8 columns]

# %%
df
# Out:
#                       Greyhound Name Earmark     Microchip    Reg Date Sex  \
# OccuredAt
# 2023-12-07 14:41:00  COOLEMORE COUNT   YVRYL  9.772000e+14  12/02/2022   B
# 2023-12-07 12:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018   D
# 2023-12-07 11:34:00    PECKIES DAFFY   VYRAJ  9.722740e+14  07/05/2021   B
# 2023-12-07 11:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018   D
# 2023-12-07 10:25:00     SHELONE KING   UUKTL  9.722740e+14  15/04/2019   D
# ...                              ...     ...           ...         ...  ..
# NaT                  KNOCKGLASS KING   VPISU  9.772000e+14  01/04/2021   D
# NaT                     HELLO HOLLIE   TDVXR  9.722740e+14  23/04/2021   B
# NaT                      SEOMRA DISC   UYIKE  9.722740e+14  04/05/2021   D
# NaT                     KILWEST NOAH   VVTMH  9.772000e+14  24/11/2021   D
# NaT                      CHEEKY CHAR    ZYH2           NaN  18/01/2022   D
#
#                      Whelp Date Retirement Type Status
# OccuredAt
# 2023-12-07 14:41:00  12/02/2022             DIE    DIE
# 2023-12-07 12:24:00  21/04/2019             RET    RET
# 2023-12-07 11:34:00  26/03/2020             RET    RET
# 2023-12-07 11:24:00  21/04/2019             RET    RAC
# 2023-12-07 10:25:00  15/04/2019             RET    RET
# ...                         ...             ...    ...
# NaT                  18/03/2020             EUT    EUT
# NaT                  04/08/2018             EUT    EUT
# NaT                  12/12/2019             EUT    EUT
# NaT                  20/09/2020             EUT    EUT
# NaT                  18/08/2020             EUT    EUT
#
# [234547 rows x 8 columns]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                  OccuredAt   Greyhound Name Earmark     Microchip    Reg Date  \
# 0      2023-12-07 14:41:00  COOLEMORE COUNT   YVRYL  9.772000e+14  12/02/2022
# 1      2023-12-07 12:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018
# 2      2023-12-07 11:34:00    PECKIES DAFFY   VYRAJ  9.722740e+14  07/05/2021
# 3      2023-12-07 11:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018
# 4      2023-12-07 10:25:00     SHELONE KING   UUKTL  9.722740e+14  15/04/2019
# ...                    ...              ...     ...           ...         ...
# 234542                 NaT  KNOCKGLASS KING   VPISU  9.772000e+14  01/04/2021
# 234543                 NaT     HELLO HOLLIE   TDVXR  9.722740e+14  23/04/2021
# 234544                 NaT      SEOMRA DISC   UYIKE  9.722740e+14  04/05/2021
# 234545                 NaT     KILWEST NOAH   VVTMH  9.772000e+14  24/11/2021
# 234546                 NaT      CHEEKY CHAR    ZYH2           NaN  18/01/2022
#
#        Sex  Whelp Date Retirement Type Status
# 0        B  12/02/2022             DIE    DIE
# 1        D  21/04/2019             RET    RET
# 2        B  26/03/2020             RET    RET
# 3        D  21/04/2019             RET    RAC
# 4        D  15/04/2019             RET    RET
# ...     ..         ...             ...    ...
# 234542   D  18/03/2020             EUT    EUT
# 234543   B  04/08/2018             EUT    EUT
# 234544   D  12/12/2019             EUT    EUT
# 234545   D  20/09/2020             EUT    EUT
# 234546   D  18/08/2020             EUT    EUT
#
# [234547 rows x 9 columns]

# %%
df["Whelp Date"] = pd.to_datetime(df["Whelp Date"])
df["OccuredAt"] = pd.to_datetime(df["OccuredAt"])
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_4612\3838613621.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Whelp Date"] = pd.to_datetime(df["Whelp Date"])

# %%
# Filter data for greyhounds with "RET" (Death) status
ret_data = df[df["Status"] == "RET"]

# %%
# Filter data for greyhounds with "RET" (Death) status and valid OccuredAt dates
ret_data = df[(df["Status"] == "RET") & (~df["OccuredAt"].isnull())]

# %%
ret_data
# Out:
#                  OccuredAt    Greyhound Name Earmark     Microchip  \
# 1      2023-12-07 12:24:00       SPOOK MAGOO   UNBET  9.722740e+14
# 2      2023-12-07 11:34:00     PECKIES DAFFY   VYRAJ  9.722740e+14
# 4      2023-12-07 10:25:00      SHELONE KING   UUKTL  9.722740e+14
# 21     2023-12-07 06:34:00       THORNEY RUN   XPHIB  9.772000e+14
# 46     2023-12-07 06:34:00  HELP MEOUT PADDY   XXLTU  9.772000e+14
# ...                    ...               ...     ...           ...
# 230694 2021-01-12 06:02:00      BALLYVOE ACE   SQDNX  9.722740e+14
# 230697 2021-01-12 06:02:00          CODE MEL   UYEVM  9.722740e+14
# 230737 2021-01-10 06:01:00          VIEW RON   UPJAA  9.722740e+14
# 230739 2021-01-10 06:01:00     BALLYGUR MING   SDDUI  9.722740e+14
# 230751 2021-01-10 06:01:00     VIEW HERMOINE   UPVXM  9.722740e+14
#
#           Reg Date Sex Whelp Date Retirement Type Status
# 1       10/10/2018   D 2019-04-21             RET    RET
# 2       07/05/2021   B 2020-03-26             RET    RET
# 4       15/04/2019   D 2019-04-15             RET    RET
# 21      03/09/2021   B 2021-01-06             RET    RET
# 46      22/12/2021   D 2021-09-09             RET    RET
# ...            ...  ..        ...             ...    ...
# 230694  24/01/2018   D 2017-05-11             RET    RET
# 230697  12/04/2021   B 2019-04-21             RET    RET
# 230737  04/10/2019   D 2019-12-06             RET    RET
# 230739  06/03/2018   B 2017-09-10             RET    RET
# 230751  04/10/2019   B 2019-12-06             RET    RET
#
# [3133 rows x 9 columns]

# %%
# Calculate the time difference in days between Whelp Date and OccuredAt
ret_data["Days_Lived"] = (ret_data["OccuredAt"] - ret_data["Whelp Date"]).dt.days
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_4612\3479783897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret_data["Days_Lived"] = (ret_data["OccuredAt"] - ret_data["Whelp Date"]).dt.days

# %%
ret_data["Days_Lived"]
# Out:
# 1         1691.0
# 2         1351.0
# 4         1697.0
# 21        1065.0
# 46         819.0
#            ...
# 230694    1342.0
# 230697     632.0
# 230737     401.0
# 230739    1218.0
# 230751     401.0
# Name: Days_Lived, Length: 3133, dtype: float64

# %%
# Plot a histogram of days lived
plt.figure(figsize=(10, 6))
plt.hist(ret_data["Days_Lived"], bins=20, color="skyblue")
plt.title("Distribution of Days Lived from Whelp Date to Retired Greyhounds")
plt.xlabel("Days Lived")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Print descriptive statistics
print(ret_data["Days_Lived"].describe())
# Out:
# count    3129.000000
# mean     1293.985618
# std       466.391978
# min        45.000000
# 25%       943.000000
# 50%      1286.000000
# 75%      1623.000000
# max      2923.000000
# Name: Days_Lived, dtype: float64

# %%
ret_data["Days_Lived"].median()
# Out:
# 1286.0

# %% [markdown]
# The distribution of the time from "Whelp Date" to "Death" is not typically expected to be normally distributed.<BR> The lifespan of living organisms, including greyhounds, can often follow more complex patterns due to various factors such as genetics, environment, health, and more. As a result, the distribution of lifespans can be skewed, have multiple peaks, or exhibit other non-normal characteristics.
#
# If you plot the distribution of days lived from "Whelp Date" to "Death," you might find that the distribution is more likely to be right-skewed. This means that there may be a larger number of greyhounds with shorter lifespans and a smaller number with longer lifespans. The presence of outliers (greyhounds with exceptionally long lifespans) could further contribute to the non-normal distribution.
#
# A histogram or a kernel density plot can provide a visual representation of the distribution. Additionally, you can use summary statistics such as mean, median, and standard deviation to quantify the central tendency and spread of the distribution.

# %%
df
# Out:
#                  OccuredAt   Greyhound Name Earmark     Microchip    Reg Date  \
# 0      2023-12-07 14:41:00  COOLEMORE COUNT   YVRYL  9.772000e+14  12/02/2022
# 1      2023-12-07 12:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018
# 2      2023-12-07 11:34:00    PECKIES DAFFY   VYRAJ  9.722740e+14  07/05/2021
# 3      2023-12-07 11:24:00      SPOOK MAGOO   UNBET  9.722740e+14  10/10/2018
# 4      2023-12-07 10:25:00     SHELONE KING   UUKTL  9.722740e+14  15/04/2019
# ...                    ...              ...     ...           ...         ...
# 234542                 NaT  KNOCKGLASS KING   VPISU  9.772000e+14  01/04/2021
# 234543                 NaT     HELLO HOLLIE   TDVXR  9.722740e+14  23/04/2021
# 234544                 NaT      SEOMRA DISC   UYIKE  9.722740e+14  04/05/2021
# 234545                 NaT     KILWEST NOAH   VVTMH  9.772000e+14  24/11/2021
# 234546                 NaT      CHEEKY CHAR    ZYH2           NaN  18/01/2022
#
#        Sex Whelp Date Retirement Type Status
# 0        B 2022-12-02             DIE    DIE
# 1        D 2019-04-21             RET    RET
# 2        B 2020-03-26             RET    RET
# 3        D 2019-04-21             RET    RAC
# 4        D 2019-04-15             RET    RET
# ...     ..        ...             ...    ...
# 234542   D 2020-03-18             EUT    EUT
# 234543   B 2018-04-08             EUT    EUT
# 234544   D 2019-12-12             EUT    EUT
# 234545   D 2020-09-20             EUT    EUT
# 234546   D 2020-08-18             EUT    EUT
#
# [234547 rows x 9 columns]

# %%
# Filter data for greyhounds with "DIE" (Death) status
die_data = df[df["Status"] == "DIE"]

# %%
die_data
# Out:
#                  OccuredAt  Greyhound Name Earmark     Microchip    Reg Date  \
# 0      2021-10-21 11:11:00    JEWEL MAIDEN   PLPIQ  9.722740e+14  29/09/2015
# 7      2022-02-27 09:30:00     BULLET ENDA   QPBVB  9.810980e+14  11/02/2016
# 11     2022-02-27 09:30:00  FLEXIBLE PANGO   QRHSP  9.810980e+14  23/09/2016
# 14     2022-02-27 09:30:00  FLEXIBLE TANGO   QRLED  9.810980e+14  23/09/2016
# 17     2021-10-09 11:17:00     BLACK RIOGA   QPYAK  9.810980e+14  02/11/2016
# ...                    ...             ...     ...           ...         ...
# 187564 2023-05-17 06:35:00             NaN   ZVTIZ  9.772000e+14  12/01/2023
# 187565 2023-05-18 06:34:00             NaN   ZHESX  9.772000e+14  01/02/2023
# 187570 2023-05-18 06:34:00             NaN   ZBXRJ  9.772000e+14  20/01/2023
# 187573 2023-06-15 06:32:00             NaN   ZTVSV  9.772000e+14  12/03/2023
# 187576 2023-09-07 06:30:00   MINDIES BLITZ   SBEVK  9.722740e+14  07/07/2023
#
#        Sex Whelp Date Retirement Type Status
# 0        B 2014-09-22             DIE    DIE
# 7        B 2015-05-04             DIE    DIE
# 11       B 2015-01-09             DIE    DIE
# 14       B 2015-01-09             DIE    DIE
# 17       D 2015-10-26             DIE    DIE
# ...     ..        ...             ...    ...
# 187564   B 2023-12-01             DIE    DIE
# 187565   D 2023-01-02             DIE    DIE
# 187570   D 2023-01-20             DIE    DIE
# 187573   D 2023-12-03             DIE    DIE
# 187576   D 2017-06-16             DIE    DIE
#
# [13198 rows x 9 columns]

# %%
# Calculate the time difference in days between Whelp Date and OccuredAt
die_data["Days_Lived"] = (die_data["OccuredAt"] - die_data["Whelp Date"]).dt.days
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_4612\1960019408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   die_data["Days_Lived"] = (die_data["OccuredAt"] - die_data["Whelp Date"]).dt.days

# %%
# Plot a histogram of days lived
plt.figure(figsize=(10, 6))
plt.hist(die_data["Days_Lived"], bins=20, color="red")
plt.title("Distribution of Days Lived from Whelp Date to Death")
plt.xlabel("Days Lived")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Print descriptive statistics
print(die_data["Days_Lived"].describe())
# Out:
# count    10713.000000
# mean       883.296462
# std        341.741981
# min       -198.000000
# 25%        655.000000
# 50%        830.000000
# 75%       1047.000000
# max       2913.000000
# Name: Days_Lived, dtype: float64

# %%
# Filter data for greyhounds with "DIE" (Death) status
eut_data = df[df["Status"] == "EUT"]

# %%
eut_data
# Out:
#                  OccuredAt   Greyhound Name Earmark     Microchip    Reg Date  \
# 7      2023-12-07 09:21:00              NaN   XDZVS  9.772000e+14  11/10/2021
# 138    2023-12-06 19:13:00  TOMAHURRA LILLY   VDBLL  9.722740e+14  10/03/2020
# 152    2023-12-06 16:57:00              NaN   XDQLJ  9.772000e+14  08/10/2021
# 158    2023-12-06 11:29:00   DRUMCASHEL MAY   XJDMS  9.772000e+14  18/11/2020
# 161    2023-12-06 11:17:00     FOXROCK JOAN   TTNJY  9.722740e+14  26/09/2018
# ...                    ...              ...     ...           ...         ...
# 234542                 NaT  KNOCKGLASS KING   VPISU  9.772000e+14  01/04/2021
# 234543                 NaT     HELLO HOLLIE   TDVXR  9.722740e+14  23/04/2021
# 234544                 NaT      SEOMRA DISC   UYIKE  9.722740e+14  04/05/2021
# 234545                 NaT     KILWEST NOAH   VVTMH  9.772000e+14  24/11/2021
# 234546                 NaT      CHEEKY CHAR    ZYH2           NaN  18/01/2022
#
#        Sex Whelp Date Retirement Type Status  Days_Lived
# 7        B 2021-11-10             EUT    EUT       757.0
# 138      B 2019-06-10             EUT    EUT      1640.0
# 152      D 2021-08-10             EUT    EUT       848.0
# 158      B 2021-07-22             EUT    EUT       867.0
# 161      B 2018-04-08             EUT    EUT      2068.0
# ...     ..        ...             ...    ...         ...
# 234542   D 2020-03-18             EUT    EUT         NaN
# 234543   B 2018-04-08             EUT    EUT         NaN
# 234544   D 2019-12-12             EUT    EUT         NaN
# 234545   D 2020-09-20             EUT    EUT         NaN
# 234546   D 2020-08-18             EUT    EUT         NaN
#
# [1014 rows x 10 columns]

# %%
# Print descriptive statistics
print(eut_data["Days_Lived"].describe())
# Out:
# count     747.000000
# mean     1066.820616
# std       488.503265
# min       -16.000000
# 25%       700.500000
# 50%      1012.000000
# 75%      1408.000000
# max      3200.000000
# Name: Days_Lived, dtype: float64

# %%
# Calculate the time difference in days between Whelp Date and OccuredAt
eut_data["Days_Lived"] = (eut_data["OccuredAt"] - eut_data["Whelp Date"]).dt.days
# Out:
# C:\Users\danma\AppData\Local\Temp\ipykernel_4612\4021014414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eut_data["Days_Lived"] = (eut_data["OccuredAt"] - eut_data["Whelp Date"]).dt.days

# %%
# Plot a histogram of days lived
plt.figure(figsize=(10, 6))
plt.hist(eut_data["Days_Lived"], bins=20, color="lime")
plt.title("Distribution of Days Lived from Whelp Date to Euthanised")
plt.xlabel("Days Lived")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# right skewed

# %%
# Count the number of updates for each earmark
updates_count = df.groupby("Earmark")["Earmark"].count()

# %%
updates_count
# Out:
# Earmark
# AAM2     8
# AAT3     4
# AAT9     7
# AAV1    12
# AAX4     5
#         ..
# ZZDB     1
# ZZK1    16
# ZZK4    10
# ZZK8     8
# ZZP2     6
# Name: Earmark, Length: 18384, dtype: int64

# %%
updates_count.mean()
# Out:
# 12.7582136640557

# %%
updates_count.describe()
# Out:
# count    18384.000000
# mean        12.758214
# std         12.554576
# min          1.000000
# 25%          1.000000
# 50%          9.000000
# 75%         21.000000
# max        100.000000
# Name: Earmark, dtype: float64
